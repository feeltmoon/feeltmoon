# %%
import pandas as pd
import numpy as np

df = pd.read_excel(r'G:\WFH\20211226_01\ECS_spec.xlsx', sheet_name='Sheet1')
df1 = pd.read_excel(r'G:\WFH\20211226_01\BGB-16673-102_V1.0.xlsx', sheet_name='CheckActions')

# %%
pd.set_option('display.max_rows', 3)
pd.set_option('display.max_columns', 10)

# %%
df = pd.DataFrame(df,columns=['Version#','Serial #','Edit Check Name','Folder OID','Form Name','Form OID','Field Label',
                               'Field OID','Related Field OID','Query Text/Mapping Text/Email','Check Type','Assigner'])
df
# Out:
#       Version#  Serial #                                    Edit Check Name  \
# 0          0.1         1  DYN_CTMSTAG_CF_DS_EOS\nDYN_CTMSTAG_CF_DS_IC\nD...
# ...        ...       ...                                                ...
# 1101       0.1      1109                             SYS_REQ_RSALRES|RS_PET
#
#                              Folder OID                   Form Name  ...  \
# 0                               Subject                     Patient  ...
# ...                                 ...                         ...  ...
# 1101  SCR, RASS\nRASFUP\nRALFUP\nRASUNS  Deauville Five-Point Scale  ...
#
#      Field OID Related Field OID       Query Text/Mapping Text/Email  \
# 0          NaN               NaN                                 NaN
# ...        ...               ...                                 ...
# 1101   RSALRES               NaN  Data is required. Please complete.
#
#         Check Type Assigner
# 0           Status  wei sun
# ...            ...      ...
# 1101  Field Checks    Yichi
#
# [1102 rows x 12 columns]

# %%
df = df.rename(columns={"Edit Check Name": "CheckName"})
df
# Out:
#       Version#  Serial #                                          CheckName  \
# 0          0.1         1  DYN_CTMSTAG_CF_DS_EOS\nDYN_CTMSTAG_CF_DS_IC\nD...
# ...        ...       ...                                                ...
# 1101       0.1      1109                             SYS_REQ_RSALRES|RS_PET
#
#                              Folder OID                   Form Name  ...  \
# 0                               Subject                     Patient  ...
# ...                                 ...                         ...  ...
# 1101  SCR, RASS\nRASFUP\nRALFUP\nRASUNS  Deauville Five-Point Scale  ...
#
#      Field OID Related Field OID       Query Text/Mapping Text/Email  \
# 0          NaN               NaN                                 NaN
# ...        ...               ...                                 ...
# 1101   RSALRES               NaN  Data is required. Please complete.
#
#         Check Type Assigner
# 0           Status  wei sun
# ...            ...      ...
# 1101  Field Checks    Yichi
#
# [1102 rows x 12 columns]

# %%
#df['CheckName'].str.strip()
#df

# %%
df1 = pd.DataFrame(df1,columns=['CheckName','ActionType','ActionString'])
#df1

# %%
df1 = df1[~df1['ActionString'].isna()]

# %%
join = pd.merge(df, df1, how='left', on=['CheckName'])
join
# Out:
#       Version#  Serial #                                          CheckName  \
# 0          0.1         1  DYN_CTMSTAG_CF_DS_EOS\nDYN_CTMSTAG_CF_DS_IC\nD...
# ...        ...       ...                                                ...
# 1101       0.1      1109                             SYS_REQ_RSALRES|RS_PET
#
#                              Folder OID                   Form Name  ...  \
# 0                               Subject                     Patient  ...
# ...                                 ...                         ...  ...
# 1101  SCR, RASS\nRASFUP\nRALFUP\nRASUNS  Deauville Five-Point Scale  ...
#
#            Query Text/Mapping Text/Email    Check Type Assigner ActionType  \
# 0                                    NaN        Status  wei sun        NaN
# ...                                  ...           ...      ...        ...
# 1101  Data is required. Please complete.  Field Checks    Yichi        NaN
#
#      ActionString
# 0             NaN
# ...           ...
# 1101          NaN
#
# [1102 rows x 14 columns]

# %%
join['IsEqual'] = (join['Query Text/Mapping Text/Email']==join['ActionString'])
join
# Out:
#       Version#  Serial #                                          CheckName  \
# 0          0.1         1  DYN_CTMSTAG_CF_DS_EOS\nDYN_CTMSTAG_CF_DS_IC\nD...
# ...        ...       ...                                                ...
# 1101       0.1      1109                             SYS_REQ_RSALRES|RS_PET
#
#                              Folder OID                   Form Name  ...  \
# 0                               Subject                     Patient  ...
# ...                                 ...                         ...  ...
# 1101  SCR, RASS\nRASFUP\nRALFUP\nRASUNS  Deauville Five-Point Scale  ...
#
#         Check Type Assigner ActionType ActionString IsEqual
# 0           Status  wei sun        NaN          NaN   False
# ...            ...      ...        ...          ...     ...
# 1101  Field Checks    Yichi        NaN          NaN   False
#
# [1102 rows x 15 columns]

# %%
join.to_excel(r'G:\WFH\20211226_01\EC_InternalQC_CheckQueryText.xlsx')
